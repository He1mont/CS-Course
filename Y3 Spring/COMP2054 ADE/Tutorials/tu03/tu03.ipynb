# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_theta(f, g, cp, cpp, n_0, min_x, max_x):
    xs = np.arange(min_x,max_x,1, dtype='int64')
    fn_ys = f(xs)
    gn_ysp = cp*g(xs)
    gn_yspp = cpp*g(xs)
    plt.axvline(x = n_0, color = 'k', linestyle='--')
    plt.scatter(x=xs, y=fn_ys, marker='x')
    plt.scatter(x=xs, y=gn_ysp, marker='.')
    plt.scatter(x=xs, y=gn_yspp, marker='.')
    plt.xlabel('n')
    plt.ylabel('$\lambda(n)$')
    plt.legend(['n_0 = '+str(n_0),'f(n)', 'c\'g(n)', 'c\'\'g(n)'])
  
    
def plot_oh_incr(f, g, c, n_0, min_x, max_x, incr):
    xs = np.arange(min_x,max_x,incr, dtype='int64')
    fn_ys = f(xs)
    gn_ys = c*g(xs)
    plt.axvline(x = n_0, color = 'k', linestyle='--')
    plt.scatter(x=xs, y=fn_ys, marker='x')
    plt.scatter(x=xs, y=gn_ys, marker='.')
    plt.xlabel('n')
    plt.ylabel('$\lambda(n)$')
    plt.legend(['n_0 = '+str(n_0),'f(n)', 'cg(n)'])
    
def plot_oh(f, g, c, n_0, min_x, max_x):
    plot_oh_incr(f, g, c, n_0, min_x, max_x, 1)

# %% [markdown]
# ## Big-Oh Definition
# Given positive functions $f(n)$ and $g(n)$, we can say that $f(n) \text{ is } O(g(n))$ if and only if there exists positive constants $c$ and $n_0$ such that: $$f(n) \leq c \cdot g(n), \forall n \geq n_0$$

# %% [markdown]
# ## Big-Oh Using Rules

# %% [markdown]
# **Drop smaller terms rule:**
#
# If $f(n) = (1 + h(n))$ and $h(n) \rightarrow 0$ as $n \rightarrow \infty$, then $f(n)$ is $O(1)$

# %% [markdown]
# ### Q1. Prove that $n^3 + 2n^2$ is $O(n^3)$ using the multiplication and drop smaller terms rules

# %% [markdown]
# By multiplication rule we have:
# $$
# n^3 + 2n^2 = n^3 \cdot (1 + 2 / n)
# $$
#
# By the plot below we know that $\lim_{n\to \infin}2/n \to 0$
#
# By drop smaller item rule we have:
# $$n^3(1) \ \text{is} \ O(n^3) $$

# %%
xs = np.arange(1,100,1, dtype='int64')
h = lambda n: 2 / (n)
ys = h(xs)

plt.plot(xs,ys, marker='.')
plt.xlabel('n')
plt.ylabel('$h(n)$')
plt.legend(['$\dfrac{2}{n}$'])

# %% [markdown]
# ### Q2. Prove that $n^3 + 2n^2 log(n)$ is $O(n^3)$ using the multiplication and drop smaller terms rules

# %% [markdown]
# By **multiplication rule** we have:
# $$
# n^3 + 2n^2 \log(n) = n^3 \cdot (1 + 2 \log(n)/ n)
# $$
#
# By the plot below we know that $\lim_{n\to \infin}2 \log(n)/n \to 0$
#
# By drop smaller item rule we have:
# $$n^3(1) \ \text{is} \ O(n^3) $$

# %%
xs = np.arange(1,10000,100, dtype='int64')
h = lambda n: (2*np.log2(n)) / (n)
ys = h(xs)

plt.plot(xs,ys,marker='.')
plt.xlabel('n')
plt.ylabel('$h(n)$')
plt.legend(['$\dfrac{2log_2n}{n}$'])

# %% [markdown]
# ## Big-Omega and Big-Theta Definitions

# %% [markdown]
# **Big-Omega:** Given positive functions $f(n)$ and $g(n)$, we can say that $f(n) \text{ is } \Omega(g(n))$ if and only if there exists strictly positive constants $c$ and $n_0$ such that:
# $$f(n) \geq c \cdot g(n), \forall n \geq n_0$$
#
# $\Omega$ expresses that a function $f(n)$ grows at least as fast as $g(n)$.
#
# **Big-Theta:** Given positive functions $f(n)$ and $g(n)$, we can say that $f(n) \text{ is } \Theta(g(n))$ if and only if there exists positive constants $c'$, $c''$ and $n_0$ such that:
#
# $$f(n) \leq c' \cdot g(n), \; f(n) \geq c'' \cdot g(n), \; \forall n \geq n_0$$
#
# $\Theta$ expresses that a function $f(n)$ grows exactly as fast as $g(n)$.

# %% [markdown]
# ### Q3. Prove that $2n + 1$ is $\Omega(3n)$ and hence $2n + 1$ is $\Theta(3n)$

# %% [markdown]
# We wanna prove $2n+1$ is $\Omega (3n)$, that is $\exist c > 0, \exist n_0$, such that
# $$
# \forall n \ge n_0, \ 2n+1 \ge c \cdot (3n)
# $$
#
# Take $c = 2/3$, we have,
# $$
# \forall n \ge n_0, \ 2n+1 \ge 2n \Rightarrow 1 \ge 0
# $$
#
# This is trivially true. Take $n_0 = 1$.
# Therefore $2n+1$ is $\Omega(3n)$ using $c = 2/3, n_0 = 1$
#
# ---
#
# We wanna prove $2n+1$ is $\Theta (3n)$, that is $\exist c' > 0, \exist c'' > 0, \exist n_0$, such that
# $$
# \forall n \ge n_0, \ 2n+1 \le c'(3n), 2n+1 \ge c'' (3n)
# $$
#
# Take $c' = 1, c'' = 2/3$, we have:
# $$
# \forall n \ge n_0, \ 2n+1 \le 1\cdot 3n, 2n+1 \ge 2/3\cdot 3n  \Rightarrow n \ge 1 , 1 \ge 0
# $$
#
# Take $n_0 = 1$, we have
# $$
# \forall n \ge 1,  n \ge 1 , 1 \ge 0
# $$
#
# Therefore $2n+1$ is $\Theta(3n)$ using $c'=1, c'' = 2/3, n_0 = 1$

# %% [markdown]
# **Plot $\Omega$**

# %%
c = 2/3.0
n_0 = 1
f = lambda n: (2*n+1)
g = lambda n: (3*n)

plot_oh(f, g, c, n_0, 0, 50)

# %% [markdown]
# **Plot $\Theta$**

# %%
cp = 1
cpp = 2/3.0
n_0 = 1
f = lambda n: (2*n+1)
g = lambda n: (3*n)

plot_theta(f, g, cp, cpp, n_0, 0, 50)

# %% [markdown]
# ## Big-Omega/Big-Theta Questions: Basics

# %% [markdown]
# ### Q4. Prove that 5 is $\Omega(1)$, and hence 5 is $\Theta(1)$

# %% [markdown]
# We wanna prove $5 \text{ is } \Omega(1)$, that is $\exist c>0, \exist n_0$ such that
# - $5 \ge c \cdot 1, \ \forall n \ge n_0$
# - $5 \geq 1, \forall n \ge n_0$ (take $c=1$)
# - $5 \geq 1, \forall n \ge 1$ (take $n_0=1$)
#
# Therefore $5$ is $\Omega(1)$ using $c=1, n_0=1$.
#
# Using $c'' = c$ and the same $n_0$ we just need to show the $\le$ case for $\Theta$.
#
# - $5 \le c' \cdot 1, \forall n \ge 1$
# - $5 \le 5, \forall n \ge 1$ (take $c'=5$)
#
# Therefore $5$ is $\Theta(1)$ using $c'=5, c''=1, n_0=1$.

# %% [markdown]
# ### Q5. Prove that $4$ is $\Omega(2)$, and hence $4$ is $\Theta(2)$

# %% [markdown]
# We wanna prove $4 \text{ is } \Omega(2)$, that is $\exist c>0, \exist n_0$ such that
#
# - $4 \ge c \cdot 2, \ \forall n \ge n_0 $
# - $4 \geq 2, \forall n \ge n_0$ (take $c=1$)
# - $4 \geq 2, \forall n \ge 1$ (take $n_0=1$)
#
# Therefore $4$ is $\Omega(2)$ using $c=1, n_0=1$.
#
# Using $c'' = c$ and the same $n_0$ we just need to show the $\le$ case for $\Theta$.
#
# - $4 \le c' \cdot 4, \forall n \ge 1$
# - $4 \le 4, \forall n \ge 1$ (take $c'=2$)
#
# Therefore $4$ is $\Theta(2)$ using $c'=2, c''=1, n_0=1$.

# %% [markdown]
# ### Q6. Prove that $2n+1$ is $\Omega(n)$, and hence $2n+1$ is $\Theta(n)$

# %% [markdown]
# We wanna prove $2n+1 \text{ is } \Omega(n)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ 2n+1 \ge c \cdot n $
# - $\forall n \ge n_0, \ 2n+1 \ge 2n \Rightarrow 1 \ge 0$ (take $c=2$)
# - $\forall n \ge 1, 1 \ge 0$ (take $n_0=1$)
#
# Therefore $2n+1$ is $\Omega(n)$ using $c=2, n_0=1$.
#
# Using $c'' = c$ and the same $n_0$ we just need to show the $\le$ case for $\Theta$.
#
# - $\forall n \ge 1, \ 2n+1 \le c' \cdot n$
# - $\forall n \ge 1, \ 2n+1 \le 3n \Rightarrow n \ge 1 $ (take $c'=3$)
#
# Therefore $2n+1$ is $\Theta(n)$ using $c'=3, c''=2, n_0=1$.

# %% [markdown]
# ## Big-Omega/Big-Theta Questions: Medium Difficulty

# %% [markdown]
# ### Q7. Prove that $n^2$ is $\Omega(2n^2)$

# %% [markdown]
# We wanna prove $n^2 \text{ is } \Omega(2n^2)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n^2 \ge c \cdot 2n^2 $
# - $\forall n \ge n_0, \ n^2 \ge 1/2 \cdot 2n^2 \Rightarrow 0 \ge 0$ (take $c=1/2$)
# - $\forall n \ge 1, 0 \ge 0$ (take $n_0=1$)
#
# Therefore $n^2$ is $\Omega(2n^2)$ using $c=1/2, n_0=1$.
#
# Using $c'' = c$ and the same $n_0$ we just need to show the $\le$ case for $\Theta$.
#
# - $\forall n \ge 1, \ n^2 \le c' \cdot 2n^2$
# - $\forall n \ge 1, \ n^2 \le 2n^2 \Rightarrow n^2 \ge 0 $ (take $c'=1$)
#
# Therefore $n^2$ is $\Theta(2n^2)$ using $c'=1, c''=1/2, n_0=1$.

# %% [markdown]
# ### Q8. Prove that $n^2-3$ is $\Omega(n^2)$

# %% [markdown]
# We wanna prove $n^2 -3 \text{ is } \Omega(n^2)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n^2 -3 \ge c \cdot n^2 $
# - $\forall n \ge n_0, \ n^2 -3 \ge 1/2 \cdot n^2 \Rightarrow n^2 \ge 6$ (take $c=1/2$)
# - $\forall n \ge 3, n^2 \ge 6$ (take $n_0=3$)
#
# Therefore $n^2 -3 \text{ is } \Omega(n^2)$ using $c=1/2, n_0=3$.
#
# Using $c'' = c$ and the same $n_0$ we just need to show the $\le$ case for $\Theta$.
#
# - $\forall n \ge 3, \ n^2-3 \le c' \cdot n^2$
# - $\forall n \ge 3, \ n^2-3 \le n^2 \Rightarrow 3 \ge 0 $ (take $c'=1$)
#
# Therefore $n^2 - 3$ is $\Theta(n^2)$ using $c'=1, c''=1/2, n_0=3$.

# %% [markdown]
# ### Q9. Prove that $n^2-5n$ is $\Omega(n^2)$, and hence is $\Theta(n^2)$

# %% [markdown]
# We wanna prove $n^2 -5n \text{ is } \Omega(n^2)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n^2 -5n \ge c \cdot n^2 $
# - $\forall n \ge n_0, \ n^2 -5n \ge 1/2 \cdot n^2 \Rightarrow n \ge 10$ (take $c=1/2$)
# - $\forall n \ge 10, n \ge 10$ (take $n_0=10$)
#
# Therefore $n^2 -5n \text{ is } \Omega(n^2)$ using $c=1/2, n_0=10$.
#
# Using $c'' = c$ and the same $n_0$ we just need to show the $\le$ case for $\Theta$.
#
# - $\forall n \ge 10, \ n^2-5n \le c' \cdot n^2$
# - $\forall n \ge 10, \ n^2-5n \le n^2 \Rightarrow 5n \ge 0 $ (take $c'=1$)
#
# Therefore $n^2 - 5n$ is $\Theta(n^2)$ using $c'=1, c''=1/2, n_0=10$.

# %% [markdown]
# ### Q10. Prove that $n^2 + 1$ is $\Omega(n^2)$

# %% [markdown]
# We wanna prove $n^2 + 1 \text{ is } \Omega(n^2)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n^2 +1 \ge c \cdot n^2 $
# - $\forall n \ge n_0, \ n^2 +1 \ge 1 \cdot n^2 \Rightarrow 1 \ge 0$ (take $c=1$)
# - $\forall n \ge 1, 1 \ge 0$ (take $n_0=1$)
#
# Therefore $n^2 +1 \text{ is } \Omega(n^2)$ using $c=1, n_0=1$.
#
# Using $c'' = c$ and the same $n_0$ we just need to show the $\le$ case for $\Theta$.
#
# - $\forall n \ge 1, \ n^2+1 \le c' \cdot n^2$
# - $\forall n \ge 1, \ n^2+1 \le 2n^2 \Rightarrow n^2 \ge 1 $ (take $c'=2$)
#
# Therefore $n^2+1$ is $\Theta(n^2)$ using $c'=2, c''=1, n_0=1$.

# %% [markdown]
# ## Little-Oh Definition

# %% [markdown]
# Given positive functions $f(n)$ and $g(n)$, we can say that $f(n) \text{ is } o(g(n))$ if **for all positive real constants $c > 0$** there exists $n_0$ such that:
#
# $$f(n) < c \cdot g(n), \forall n \geq n_0$$
#
# **<u>Important:</u>**
# + $c \in \R^+_*$
# + $\R^+_* = \{x \in \R | x > 0\}$

# %% [markdown]
# ### Q11. Prove or disprove that 5 is $o(1)$

# %% [markdown]
# We wanna prove $5 \text{ is } o(1)$, that is $\forall c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ 5 < c \cdot 1 $
#
# This is **NOT valid** for $0 < c \le 5$, therefore it is **disproven**.

# %% [markdown]
# ### Q12. Prove or disprove that 5 is $o(n)$

# %% [markdown]
# We wanna prove $5 \text{ is } o(n)$, that is $\forall c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ 5 < c \cdot n \Rightarrow n > 5/c$
# - $\forall n \ge 5/c + 1, n > 5/c$ (take $n_0 = 5/c + 1$)
#
# Therefore $5$ is $o(n)$ using $n_0=5/c + 1$.

# %% [markdown]
# ## Little-Oh Questions

# %% [markdown]
# ### Q13. Prove or disprove that $n$ is $o(n^2)$

# %% [markdown]
# We wanna prove $n \text{ is } o(n^2)$, that is $\forall c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n < c \cdot n^2 \Rightarrow n > c$
# - $\forall n \ge c+1, n > c$ (take $n_0 = c + 1$)
#
# Therefore $n$ is $o(n^2)$ using $n_0= c+1$.

# %% [markdown]
# ### Q14. Prove or disprove that $1$ is $o(log\;n)$

# %% [markdown]
# We wanna prove $1 \text{ is } o(\log n)$, that is $\forall c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ 1 < c \cdot \log n \Rightarrow n > \sqrt[c]{2}$
# - $\forall n \ge \sqrt[c]{2} + 1, n > \sqrt[c]{2}$ (take $n_0 = \sqrt[c]{2} + 1$)
#
# Therefore $1$ is $o(\log n)$ using $n_0= \sqrt[c]{2}+1$.

# %% [markdown]
# ### Q15. Prove or disprove that $log\;n$ is $o(1)$

# %% [markdown]
# We wanna prove $\log n \text{ is } o(1)$, that is $\forall c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ \log n < c \cdot 1 \Rightarrow n < 2^c $
#
# This is **NOT valid** for $n = n_0 = 2^c + 1$, therefore it is **disproven**.

# %% [markdown]
# ## Additional Practice Questions (more challenging)

# %% [markdown]
# ### Q16. Prove or disprove that $1$ is $\Omega(n)$

# %% [markdown]
# We wanna prove $1 \text{ is } \Omega(n)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ 1 \ge c \cdot n \Rightarrow n \le 1/c$
#
# This is **NOT valid** for $n = n_0 = 1/c + 1$, therefore it is **disproven**.

# %% [markdown]
# ### Q17. Prove or disprove that $n$ is $\Omega(1)$

# %% [markdown]
# We wanna prove $n \text{ is } \Omega(1)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n \ge c \cdot 1$
# - $\forall n \ge n_0, \ n \ge 1$ (take $c = 1$)
# - $\forall n \ge 1, \ n \ge 1$ (take $n_0 = 1$)
#
# Therefore $n$ is $\Omega(1)$ using $c = 1, n_0=1$.

# %% [markdown]
# ### Q18. Prove or disprove that $n^2$ is $\Omega(n)$

# %% [markdown]
# We wanna prove $n^2 \text{ is } \Omega(n)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n^2 \ge c \cdot n \Rightarrow n > c$
# - $\forall n \ge n_0, \ n \ge 1$ (take $c = 1$)
# - $\forall n \ge 1, \ n \ge 1$ (take $n_0 = 1$)
#
# Therefore $n^2$ is $\Omega(n)$ using $c = 1, n_0=1$.

# %% [markdown]
# ### Q19. Prove or disprove that $n$ is $o(n\;log\;n)$

# %% [markdown]
# We wanna prove $n \text{ is } o(n \log n)$, that is $\forall c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n < c \cdot n \log n \Rightarrow n > 2^{1/c} $
# - $\forall n \ge 2^{1/c} + 1, \ n > 2^{1/c} $ (take $n_0 = 2^{1/c} + 1 $)
#
# Therefore $n \text{ is } o(n \log n)$ using $n_0 = 2^{1/c} + 1$

# %% [markdown]
# ### Q20. Given that $f(n) = n^2$ if $n$ is even, and $f(n) = n$ if $n$ is odd. From the definitions find the $O$ and $\Omega$ behaviours of $f(n)$.
#
# Warning: be careful to find a single $c$ that works for all $n$, not separate $c$ for even and odd $n$

# %% [markdown]
# We wanna prove $f(n) \text{ is } O(n^2)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ f(n) \le c \cdot n^2 $
# - (odd case) $\forall n \ge n_0, \ n \le c \cdot n^2$
# - (even case) $\forall n \ge n_0, \ n^2 \le c \cdot n^2$
#
# Take $c = 1$, we have
#
# - (odd case) $\forall n \ge n_0, \ n \le  n^2 \Rightarrow n \ge 1$
# - (even case) $\forall n \ge n_0, \ n^2 \le n^2 \Rightarrow 0 \ge 0$
#
# These are trivially true so we could take $n_0 = 1$.
#
# Therefore $f(n) \text{ is } O(n^2)$ using $c = 1, n_0 = 1$
#
# ---
#
# We wanna prove $f(n) \text{ is } \Omega(n)$, that is $\exist c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ f(n) \ge c \cdot n $
# - (odd case) $\forall n \ge n_0, \ n \ge c \cdot n$
# - (even case) $\forall n \ge n_0, \ n^2 \ge c \cdot n$
#
# Take $c = 1$, we have
#
# - (odd case) $\forall n \ge n_0, \ n \ge  n \Rightarrow 0 \ge 0$
# - (even case) $\forall n \ge n_0, \ n^2 \ge n \Rightarrow n \ge 1$
#
# These are trivially true so we could take $n_0 = 1$.
#
# Therefore $f(n) \text{ is } \Omega(n)$ using $c = 1, n_0 = 1$

# %% [markdown]
# ### Q21. Prove or disprove that $n\;log\;n$ is $o(n^2)$

# %% [markdown]
# We wanna prove $n \log \text{ is } o(n^2)$, that is $\forall c>0, \exist n_0$ such that
#
# - $\forall n \ge n_0, \ n \log n < c \cdot n^2 \log n \Rightarrow c > \log n / n $
#
# Since $\lim_{n\to \infin} \log n / n \to 0$, for any $c$, there exists an large enough $n_0$ such that $c > \log n_0 / n_0$
#
# Therefore $n \log n \text{ is } o(n^2)$.
